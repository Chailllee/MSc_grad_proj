# %% [markdown]
# # Import

# %%
import os
import pandas as pd

# %%
# 定义文件夹路径
input_folder = r"D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon"
output_folder = r"D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2"

# 确保输出文件夹存在
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
# 定义研究区域文件夹
study_areas = ["Camden", "City of London", "Islington", "Kensington and Chelsea", "Lambeth", "Southwark", "Westminster"]

# %% [markdown]
# #  Unify TimeScale of each.csv

# %%
# Process each study area
for area in study_areas:
    area_input_folder = os.path.join(input_folder, area)
    area_output_folder = os.path.join(output_folder, area)
    os.makedirs(area_output_folder, exist_ok=True)

    # Process each CSV file in the study area folder
    for filename in os.listdir(area_input_folder):
        if "NO2" in filename or "PM2.5" in filename:
            file_path = os.path.join(area_input_folder, filename)
            
            # Read the CSV file with encoding handling
            try:
                df = pd.read_csv(file_path, encoding='utf-8')
            except UnicodeDecodeError:
                try:
                    df = pd.read_csv(file_path, encoding='latin1')
                except Exception as e:
                    print(f"Failed to read {file_path} with error: {e}")
                    continue
            
            # Check and rename columns if necessary
            if 'Category' not in df.columns:
                print(f"'Category' column not found in {file_path}. Available columns: {df.columns}")
                continue
            
            # Clean data by dropping NaN values
            df = df.dropna()
            
            # Extract the date from 'Category' column
            df['Date'] = pd.to_datetime(df['Category'], dayfirst=True).dt.date
            
            # Determine the air quality type (NO2 or PM2.5)
            if "NO2" in filename:
                pollutant_type = "NO2"
                pollutant_column = "Nitrogen dioxide"
            elif "PM2.5" in filename:
                pollutant_type = "PM2.5"
                pollutant_column = "PM<sub>2.5</sub> particulates"
            else:
                continue
            
            # Calculate daily max, mean, and min values
            daily_stats = df.groupby('Date')[pollutant_column].agg(['mean', 'max', 'min']).reset_index()
            daily_stats.columns = ['Date', f'{pollutant_type}_mean', f'{pollutant_type}_max', f'{pollutant_type}_min']
            
            # Generate the new file name
            new_filename = filename.replace("Breathe London - ", "").replace(f" - {pollutant_type}.csv", f"_{pollutant_type}.csv")
            new_file_path = os.path.join(area_output_folder, new_filename)
            
            # Save the new CSV file
            daily_stats.to_csv(new_file_path, index=False, encoding='utf-8')

            print(f"Processed and saved: {new_file_path}")
# Out:
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Camden\Ampthill Square Estate_NO2.csv
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Camden\Ampthill Square Estate_PM2.5.csv
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Camden\Brunswick Centre_NO2.csv
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Camden\Brunswick Centre_PM2.5.csv
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Camden\Christopher Hatton Primary School_NO2.csv
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Camden\Christopher Hatton Primary School_PM2.5.csv
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Camden\Falcon Building, Bloomsbury_NO2.csv
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Camden\Falcon Building, Bloomsbury_PM2.5.csv
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Camden\Gospel Oak Primary School_NO2.csv
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Camden\Gospel Oak Primary School_PM2.5.csv
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Camden\Great Ormond Street Hospital_NO2.csv
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Camden\Great Ormond Street Hospital - Paul O’Gorman building_NO2.csv
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Camden\Great Ormond Street Hospital - Paul O’Gorman building_PM2.5.csv
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Camden\Great Ormond Street Hospital_PM2.5.csv
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Camden\Royal Free Hospital_NO2.csv
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Camden\Royal Free Hospital_PM2.5.csv
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Camden\Whitfield Nursery Playground_NO2.csv
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Camden\Whitfield Nursery Playground_PM2.5.csv
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\City of London\Byward Street - Great Tower Street_NO2.csv
# Failed to read D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon\City of London\Breathe London - Byward Street - Great Tower Street - NO2.jpeg with error: Error tokenizing data. C error: Expected 1 fields in line 7, saw 2
#
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\City of London\Byward Street - Great Tower Street_PM2.5.csv
# Failed to read D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon\City of London\Breathe London - Byward Street - Great Tower Street - PM2.5.jpeg with error: Error tokenizing data. C error: Expected 1 fields in line 7, saw 2
#
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\City of London\Middlesex Street Estate_NO2.csv
# Failed to read D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon\City of London\Breathe London - Middlesex Street Estate - NO2.jpeg with error: Error tokenizing data. C error: Expected 1 fields in line 7, saw 2
#
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\City of London\Middlesex Street Estate_PM2.5.csv
# Failed to read D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon\City of London\Breathe London - Middlesex Street Estate - PM2.5.jpeg with error: Error tokenizing data. C error: Expected 1 fields in line 7, saw 2
#
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Islington\Air on the Green_NO2.csv
# Failed to read D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon\Islington\Breathe London - Air on the Green - NO2.jpeg with error: Error tokenizing data. C error: Expected 1 fields in line 7, saw 2
#
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Islington\Air on the Green_PM2.5.csv
# Failed to read D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon\Islington\Breathe London - Air on the Green - PM2.5.jpeg with error: Error tokenizing data. C error: Expected 1 fields in line 7, saw 2
#
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Islington\Canonbury Primary_NO2.csv
# Failed to read D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon\Islington\Breathe London - Canonbury Primary - NO2.jpeg with error: Error tokenizing data. C error: Expected 1 fields in line 7, saw 2
#
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Islington\Canonbury Primary_PM2.5.csv
# Failed to read D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon\Islington\Breathe London - Canonbury Primary - PM2.5.jpeg with error: Error tokenizing data. C error: Expected 1 fields in line 7, saw 2
#
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Islington\Finsbury Park_NO2.csv
# Failed to read D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon\Islington\Breathe London - Finsbury Park - NO2.jpeg with error: Error tokenizing data. C error: Expected 1 fields in line 7, saw 2
#
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Islington\Finsbury Park_PM2.5.csv
# Failed to read D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon\Islington\Breathe London - Finsbury Park - PM2.5.jpeg with error: Error tokenizing data. C error: Expected 1 fields in line 7, saw 2
#
# Processed and saved: D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon2\Islington\Offord Road Green Alliance_NO2.csv
# Failed to read D:\File_auto\0_UCL_CASA\OneDrive - University College London\Xiaoyi_dissertation\Analysis\Data\AirQuality\BreatheLondon\